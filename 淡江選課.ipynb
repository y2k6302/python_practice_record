# %%
#成功版本
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import time

#把所有的self都刪掉
driver = webdriver.Firefox()    #要用甚麼瀏覽器開啟
driver.implicitly_wait(30)      #必須要有
base_url = "http://www.ais.tku.edu.tw/"    #起始頁面的url
driver.get(base_url + "/elecos/login.aspx")  #必須要有

# driver.find_element_by_id("txtStuNo").send_keys("405550269")
# driver.find_element_by_id("txtPSWD").send_keys("k2r4d0214")
# driver.find_element_by_id("btnLogin").click()

for i in range(0,99999999):

    driver.get(base_url + "/elecos/login.aspx")  #必須要有
    driver.find_element_by_id("txtStuNo").send_keys("405550269")
    driver.find_element_by_id("txtPSWD").send_keys("k2r4d0214")
    driver.find_element_by_id("btnLogin").click()
    
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3755")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3744")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3684")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3695")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3490")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3480")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3481")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3745")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3584")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3585")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3734")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3731")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3477")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3478")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3632")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3640")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3768")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3481")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3493")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3490")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3745")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3566")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3570")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3688")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3694")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3700")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3754")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3661")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3742")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3586")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3587")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3727")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3573")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3682")
    driver.find_element_by_id("btnAdd").click()
    time.sleep(4)
for i in range(0,99999999):

    driver.get(base_url + "/elecos/login.aspx")  #必須要有
    driver.find_element_by_id("txtStuNo").send_keys("405550269")
    driver.find_element_by_id("txtPSWD").send_keys("k2r4d0214")
    driver.find_element_by_id("btnLogin").click()
    
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3755")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3744")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3684")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3695")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3490")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3480")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3481")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3745")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3584")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3585")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3734")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3731")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3477")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3478")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3632")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3640")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3768")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3481")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3493")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3490")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3745")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3566")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3570")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3688")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3694")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3700")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3754")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3661")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3742")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3586")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3587")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3727")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3573")
    driver.find_element_by_id("btnAdd").click()
    driver.find_element_by_id("txtCosEleSeq").clear()
    driver.find_element_by_id("txtCosEleSeq").send_keys("3682")
    driver.find_element_by_id("btnAdd").click()
    time.sleep(4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1749a99471c8> in <module>()
#      40     driver.find_element_by_id("txtCosEleSeq").clear()
#      41     driver.find_element_by_id("txtCosEleSeq").send_keys("3490")
# ---> 42     driver.find_element_by_id("btnAdd").click()
#      43     driver.find_element_by_id("txtCosEleSeq").clear()
#      44     driver.find_element_by_id("txtCosEleSeq").send_keys("3480")
#
# C:\Users\user\Anaconda2\lib\site-packages\selenium\webdriver\remote\webelement.pyc in click(self)
#      70     def click(self):
#      71         """Clicks the element."""
# ---> 72         self._execute(Command.CLICK_ELEMENT)
#      73
#      74     def submit(self):
#
# C:\Users\user\Anaconda2\lib\site-packages\selenium\webdriver\remote\webelement.pyc in _execute(self, command, params)
#     459             params = {}
# ...
